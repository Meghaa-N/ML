# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.kdeplot(df['petal_length'],cut=0)
df.petal_length.max()
# Out:
# 6.9

# %% [markdown]
# &8764
